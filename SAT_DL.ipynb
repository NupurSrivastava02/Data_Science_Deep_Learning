# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# Out:
# C:\Users\NUPUR SRIVASTAVA\.conda\envs\deepl\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
dataset = pd.read_csv('sat.csv')

# %%
dataset
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
plt.scatter(dataset['SAT'],dataset['GPA'])
plt.show()

# %%
X = dataset.iloc[:,0].values

# %%
X
# Out:
# array([1714, 1664, 1760, 1685, 1693, 1670, 1764, 1764, 1792, 1850, 1735,
#        1775, 1735, 1712, 1773, 1872, 1755, 1674, 1842, 1786, 1761, 1722,
#        1663, 1687, 1974, 1826, 1787, 1821, 2020, 1794, 1769, 1934, 1775,
#        1855, 1880, 1849, 1808, 1954, 1777, 1831, 1865, 1850, 1966, 1702,
#        1990, 1925, 1824, 1956, 1857, 1979, 1802, 1855, 1907, 1634, 1879,
#        1887, 1730, 1953, 1781, 1891, 1964, 1808, 1893, 2041, 1893, 1832,
#        1850, 1934, 1861, 1931, 1933, 1778, 1975, 1934, 2021, 2015, 1997,
#        2020, 1843, 1936, 1810, 1987, 1962, 2050], dtype=int64)

# %%
y = dataset.iloc[:,1].values

# %%
y
# Out:
# array([2.4 , 2.52, 2.54, 2.74, 2.83, 2.91, 3.  , 3.  , 3.01, 3.01, 3.02,
#        3.07, 3.08, 3.08, 3.12, 3.17, 3.17, 3.17, 3.17, 3.19, 3.19, 3.19,
#        3.2 , 3.21, 3.24, 3.28, 3.28, 3.28, 3.28, 3.28, 3.28, 3.28, 3.29,
#        3.29, 3.29, 3.31, 3.32, 3.34, 3.37, 3.37, 3.37, 3.38, 3.38, 3.39,
#        3.39, 3.4 , 3.4 , 3.4 , 3.41, 3.41, 3.41, 3.42, 3.42, 3.42, 3.44,
#        3.47, 3.47, 3.47, 3.47, 3.48, 3.49, 3.49, 3.5 , 3.51, 3.51, 3.52,
#        3.52, 3.54, 3.58, 3.58, 3.59, 3.59, 3.6 , 3.6 , 3.61, 3.62, 3.64,
#        3.65, 3.71, 3.71, 3.71, 3.73, 3.76, 3.81])

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([
    Dense(5,activation='relu',input_dim=1,kernel_regularizer=keras.regularizers.l2(0.001)),
    Dense(5,activation='relu'),
    Dense(5,activation='relu'),
    Dense(1)
    
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 5)                 10
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 6
# ...
# Total params: 76
# Trainable params: 76
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error',optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0001))

# %%
model.fit(X,y,epochs=500)
# Out:
# Epoch 1/500
# 3/3 [==============================] - 0s 2ms/step - loss: 100915.3359
# Epoch 2/500
# 3/3 [==============================] - 0s 2ms/step - loss: 98393.4844
# Epoch 3/500
# 3/3 [==============================] - 0s 2ms/step - loss: 96249.3047
# Epoch 4/500
# 3/3 [==============================] - 0s 3ms/step - loss: 94313.6328
# Epoch 5/500
# 3/3 [==============================] - 0s 2ms/step - loss: 92499.5469
# Epoch 6/500
# 3/3 [==============================] - 0s 3ms/step - loss: 90767.1328
# Epoch 7/500
# 3/3 [==============================] - 0s 1ms/step - loss: 89098.7109
# Epoch 8/500
# 3/3 [==============================] - 0s 2ms/step - loss: 87473.6328
# Epoch 9/500
# 3/3 [==============================] - 0s 2ms/step - loss: 85892.3047
# Epoch 10/500
# 3/3 [==============================] - 0s 2ms/step - loss: 84341.3594
# Epoch 11/500
# 3/3 [==============================] - 0s 2ms/step - loss: 82818.5000
# Epoch 12/500
# ...

# %%
plt.scatter(dataset['SAT'],dataset['GPA'])
plt.plot(X,model.predict(X),color='red')
plt.show()
